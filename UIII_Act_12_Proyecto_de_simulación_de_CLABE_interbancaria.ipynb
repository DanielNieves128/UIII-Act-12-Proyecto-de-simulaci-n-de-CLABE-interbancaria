# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielNieves128/UIII-Act-12-Proyecto-de-simulaci-n-de-CLABE-interbancaria/blob/main/UIII_Act_12_Proyecto_de_simulaci%C3%B3n_de_CLABE_interbancaria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###26/05/26
# #Daniel Nieves NL=45
# ##Profesor:Eliseo Nava
# ##Clase:CLABE interbancaria
# ##Especialidad:Inteligencia Artificial

# %%
# Simulador de IA Bancaria - CLABE Interbancaria
# Programación Orientada a Objetos

class ClabeInterbancaria:

    def __init__(self, identificacion, monto, fecha_hora, banco_emisor, banco_receptor):
        self.identificacion = identificacion
        self.monto = monto
        self.fecha_hora = fecha_hora
        self.banco_emisor = banco_emisor
        self.banco_receptor = banco_receptor

    def verificar_datos_bancarios(self):
        print("\n IA: Verificando datos bancarios...")
        print("Datos verificados correctamente.")

    def transferir_fondos(self):
        print(f"Transferencia de ${self.monto:.2f} realizada.")

    def registrar_operacion(self):
        print("Operación registrada en la base de datos.")

    def notificar_transaccion(self):
        print("Notificación enviada a los bancos involucrados.")

    def confirmar_recepcion(self):
        print("✔ Fondos recibidos por el banco receptor.")


# Lista para almacenar operaciones
operaciones = []

while True:

    print("\n" + "="*50)
    print("      SISTEMA IA CLABE INTERBANCARIA")
    print("="*50)
    print("1. Registrar transferencia")
    print("2. Mostrar transferencias")
    print("3. Salir")
    print("="*50)

    opcion = input("Seleccione una opción: ")

    if opcion == "1":

        print("\n--- NUEVA TRANSFERENCIA ---")

        identificacion = input("Número de identificación: ")
        monto = float(input("Monto de transferencia: "))
        fecha_hora = input("Fecha y hora de envío: ")
        banco_emisor = input("Banco emisor: ")
        banco_receptor = input("Banco receptor: ")

        transferencia = ClabeInterbancaria(
            identificacion,
            monto,
            fecha_hora,
            banco_emisor,
            banco_receptor
        )

        print("\n--- PROCESO INTELIGENTE ---")
        transferencia.verificar_datos_bancarios()
        transferencia.transferir_fondos()
        transferencia.registrar_operacion()
        transferencia.notificar_transaccion()
        transferencia.confirmar_recepcion()

        operaciones.append(transferencia)

        print("\nTransferencia almacenada correctamente.")

    elif opcion == "2":

        if len(operaciones) == 0:
            print("\nNo existen transferencias registradas.")
        else:

            print("\nLISTADO DE TRANSFERENCIAS")
            print("-"*120)

            print(
                f"{'ID':<15}"
                f"{'MONTO':<15}"
                f"{'FECHA Y HORA':<25}"
                f"{'BANCO EMISOR':<30}"
                f"{'BANCO RECEPTOR':<30}"
            )

            print("-"*120)

            for op in operaciones:
                print(
                    f"{op.identificacion:<15}"
                    f"${op.monto:<14.2f}"
                    f"{op.fecha_hora:<25}"
                    f"{op.banco_emisor:<30}"
                    f"{op.banco_receptor:<30}"
                )

            print("-"*120)

    elif opcion == "3":
        print("\n Gracias por utilizar el Sistema IA CLABE Interbancaria.")
        break

    else:
        print("\n Opción no válida.")
# Out:
# ...
#       SISTEMA IA CLABE INTERBANCARIA
# ...
# 1. Registrar transferencia
# 2. Mostrar transferencias
# 3. Salir
# ...
# Seleccione una opción: 1
#
# --- NUEVA TRANSFERENCIA ---
# Número de identificación: 12345678910
# Monto de transferencia: 1500
# Fecha y hora de envío: 10/06/26
# Banco emisor: BBVA
# Banco receptor: Banco Azteca
#
# --- PROCESO INTELIGENTE ---
#
#  IA: Verificando datos bancarios...
# Datos verificados correctamente.
# Transferencia de $1500.00 realizada.
# Operación registrada en la base de datos.
# Notificación enviada a los bancos involucrados.
# ✔ Fondos recibidos por el banco receptor.
#
# Transferencia almacenada correctamente.
#
# ...
#       SISTEMA IA CLABE INTERBANCARIA
# ...
# 1. Registrar transferencia
# 2. Mostrar transferencias
# 3. Salir
# ...
# Seleccione una opción: 2
#
# LISTADO DE TRANSFERENCIAS
# ------------------------------------------------------------------------------------------------------------------------
# ...

# %%
# Simulador de IA Bancaria - CLABE Interbancaria
# Programación Orientada a Objetos

class ClabeInterbancaria:

    def __init__(self, identificacion, monto, fecha_hora, banco_emisor, banco_receptor):
        self.identificacion = identificacion
        self.monto = monto
        self.fecha_hora = fecha_hora
        self.banco_emisor = banco_emisor
        self.banco_receptor = banco_receptor

    def verificar_datos_bancarios(self):
        print("\n IA: Verificando datos bancarios...")
        print("Datos verificados correctamente.")

    def transferir_fondos(self):
        print(f"Transferencia de ${self.monto:.2f} realizada.")

    def registrar_operacion(self):
        print("Operación registrada en la base de datos.")

    def notificar_transaccion(self):
        print("Notificación enviada a los bancos involucrados.")

    def confirmar_recepcion(self):
        print("✔ Fondos recibidos por el banco receptor.")


# Lista para almacenar operaciones
operaciones = []

while True:

    print("\n" + "="*50)
    print("      SISTEMA IA CLABE INTERBANCARIA")
    print("="*50)
    print("1. Registrar transferencia")
    print("2. Mostrar transferencias")
    print("3. Salir")
    print("="*50)

    opcion = input("Seleccione una opción: ")

    if opcion == "1":

        print("\n--- NUEVA TRANSFERENCIA ---")

        identificacion = input("Número de identificación: ")
        monto = float(input("Monto de transferencia: "))
        fecha_hora = input("Fecha y hora de envío: ")
        banco_emisor = input("Banco emisor: ")
        banco_receptor = input("Banco receptor: ")

        transferencia = ClabeInterbancaria(
            identificacion,
            monto,
            fecha_hora,
            banco_emisor,
            banco_receptor
        )

        print("\n--- PROCESO INTELIGENTE ---")
        transferencia.verificar_datos_bancarios()
        transferencia.transferir_fondos()
        transferencia.registrar_operacion()
        transferencia.notificar_transaccion()
        transferencia.confirmar_recepcion()

        operaciones.append(transferencia)

        print("\nTransferencia almacenada correctamente.")

    elif opcion == "2":

        if len(operaciones) == 0:
            print("\nNo existen transferencias registradas.")
        else:

            print("\nLISTADO DE TRANSFERENCIAS")
            print("-"*120)

            print(
                f"{'ID':<15}"
                f"{'MONTO':<15}"
                f"{'FECHA Y HORA':<25}"
                f"{'BANCO EMISOR':<30}"
                f"{'BANCO RECEPTOR':<30}"
            )

            print("-"*120)

            for op in operaciones:
                print(
                    f"{op.identificacion:<15}"
                    f"${op.monto:<14.2f}"
                    f"{op.fecha_hora:<25}"
                    f"{op.banco_emisor:<30}"
                    f"{op.banco_receptor:<30}"
                )

            print("-"*120)

    elif opcion == "3":
        print("\n Gracias por utilizar el Sistema IA CLABE Interbancaria.")
        print("Creado por Daniel Nieves")
        break

    else:
        print("\n Opción no válida.")
# Out:
# ...
#       SISTEMA IA CLABE INTERBANCARIA
# ...
# 1. Registrar transferencia
# 2. Mostrar transferencias
# 3. Salir
# ...
# Seleccione una opción: 09213013927395
#
#  Opción no válida.
#
# ...
#       SISTEMA IA CLABE INTERBANCARIA
# ...
# 1. Registrar transferencia
# 2. Mostrar transferencias
# 3. Salir
# ...
# Seleccione una opción: 1
#
# --- NUEVA TRANSFERENCIA ---
# Número de identificación: 9423949384038
# Monto de transferencia: 1490
# Fecha y hora de envío: 12/3/3
# Banco emisor: BBVA
# Banco receptor: Banco Azteca
#
# --- PROCESO INTELIGENTE ---
#
#  IA: Verificando datos bancarios...
# Datos verificados correctamente.
# Transferencia de $1490.00 realizada.
# Operación registrada en la base de datos.
# Notificación enviada a los bancos involucrados.
# ✔ Fondos recibidos por el banco receptor.
#
# Transferencia almacenada correctamente.
#
# ...
#       SISTEMA IA CLABE INTERBANCARIA
# ...
# 1. Registrar transferencia
# 2. Mostrar transferencias
# 3. Salir
# ...
# Seleccione una opción: 2
#
# LISTADO DE TRANSFERENCIAS
# ...

# %%
# Simulador de IA Bancaria - CLABE Interbancaria
# Programación Orientada a Objetos

class ClabeInterbancaria:

    def __init__(self, identificacion, monto, fecha_hora, banco_emisor, banco_receptor):
        self.identificacion = identificacion
        self.monto = monto
        self.fecha_hora = fecha_hora
        self.banco_emisor = banco_emisor
        self.banco_receptor = banco_receptor

    def verificar_datos_bancarios(self):
        print("\n IA: Verificando datos bancarios...")
        print("Datos verificados correctamente.")

    def transferir_fondos(self):
        print(f"Transferencia de ${self.monto:.2f} realizada.")

    def registrar_operacion(self):
        print("Operación registrada en la base de datos.")

    def notificar_transaccion(self):
        print("Notificación enviada a los bancos involucrados.")

    def confirmar_recepcion(self):
        print("✔ Fondos recibidos por el banco receptor.")


# Lista para almacenar operaciones
operaciones = []

while True:

    print("\n" + "="*50)
    print("      SISTEMA IA CLABE INTERBANCARIA")
    print("="*50)
    print("1. Registrar transferencia")
    print("2. Mostrar transferencias")
    print("3. Salir")
    print("="*50)

    opcion = input("Seleccione una opción: ")

    if opcion == "1":

        print("\n--- NUEVA TRANSFERENCIA ---")

        identificacion = input("Número de identificación: ")
        monto = float(input("Monto de transferencia: "))
        fecha_hora = input("Fecha y hora de envío: ")
        banco_emisor = input("Banco emisor: ")
        banco_receptor = input("Banco receptor: ")

        transferencia = ClabeInterbancaria(
            identificacion,
            monto,
            fecha_hora,
            banco_emisor,
            banco_receptor
        )

        print("\n--- PROCESO INTELIGENTE ---")
        transferencia.verificar_datos_bancarios()
        transferencia.transferir_fondos()
        transferencia.registrar_operacion()
        transferencia.notificar_transaccion()
        transferencia.confirmar_recepcion()

        operaciones.append(transferencia)

        print("\nTransferencia almacenada correctamente.")

    elif opcion == "2":

        if len(operaciones) == 0:
            print("\nNo existen transferencias registradas.")
        else:

            print("\nLISTADO DE TRANSFERENCIAS")
            print("-"*120)

            print(
                f"{'ID':<15}"
                f"{'MONTO':<15}"
                f"{'FECHA Y HORA':<25}"
                f"{'BANCO EMISOR':<30}"
                f"{'BANCO RECEPTOR':<30}"
            )

            print("-"*120)

            for op in operaciones:
                print(
                    f"{op.identificacion:<15}"
                    f"${op.monto:<14.2f}"
                    f"{op.fecha_hora:<25}"
                    f"{op.banco_emisor:<30}"
                    f"{op.banco_receptor:<30}"
                )

            print("-"*120)

    elif opcion == "3":
        print("\n Gracias por utilizar el Sistema IA CLABE Interbancaria.")
        print("Creado por Daniel Nieves")
        break

    else:
        print("\n Opción no válida.")
# Out:
# ...
#       SISTEMA IA CLABE INTERBANCARIA
# ...
# 1. Registrar transferencia
# 2. Mostrar transferencias
# 3. Salir
# ...
# Seleccione una opción: 1
#
# --- NUEVA TRANSFERENCIA ---
# Número de identificación: 89593059752
# Monto de transferencia: 1800
# Fecha y hora de envío: 12/09/24
# Banco emisor: BBVA
# Banco receptor: Banco Azteca
#
# --- PROCESO INTELIGENTE ---
#
#  IA: Verificando datos bancarios...
# Datos verificados correctamente.
# Transferencia de $1800.00 realizada.
# Operación registrada en la base de datos.
# Notificación enviada a los bancos involucrados.
# ✔ Fondos recibidos por el banco receptor.
#
# Transferencia almacenada correctamente.
#
# ...
#       SISTEMA IA CLABE INTERBANCARIA
# ...
# 1. Registrar transferencia
# 2. Mostrar transferencias
# 3. Salir
# ...
# Seleccione una opción: 2
#
# LISTADO DE TRANSFERENCIAS
# ------------------------------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ![](https://raw.githubusercontent.com/DanielNieves128/UIII-Act-12-Proyecto-de-simulaci-n-de-CLABE-interbancaria/refs/heads/main/CLABE%20interbancaria.png)
